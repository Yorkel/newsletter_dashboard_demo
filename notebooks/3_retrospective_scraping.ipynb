# %%
import pandas as pd

# %%
# Load your merged dataset (the one with organisations + links)
df = pd.read_csv("/workspaces/ERP_Newsletter/data/data04_full_articles_scraped/newsletter_full_articles_with_items.csv")

# %%
# Your shortlist
target_orgs = [
    "schools_week",
    "uk_government",
    "guardian",
    "epi",
    "nfer",
    "conversation",
    "bera",
    "fft_ed_datalab",
    "nuffield",
    "teacher_tapp",
    "bbc",
    "fed",
    "ifg",
    "childrens_commissioner",
    "upen",
    "ippr",
    "chartered_college_of_teaching",
    "5rights_foundation",
    "ukri",
    "ippo",
    "nesta",
    "national_audit_office",
    "cct",
    "national_literacy_trust",
    "british_academy",
    "ifs",
    "uk_parliament",
]

# %%
# Filter rows for those organisations
df_filtered = df[df["organisation"].isin(target_orgs)].copy()

# %%
# Check how many rows per organisation
counts = df_filtered["organisation"].value_counts()
print(counts)
# Out:
# organisation
# schools_week                     138
# uk_government                     65
# guardian                          25
# nfer                              24
# epi                               23
# uk_parliament                     21
# bera                              20
# conversation                      19
# fft_ed_datalab                    13
# teacher_tapp                      11
# nuffield                          11
# upen                              11
# bbc                               10
# british_academy                   10
# ifs                                9
# childrens_commissioner             9
# ifg                                9
# fed                                9
# ukri                               7
# 5rights_foundation                 5
# ippr                               5
# chartered_college_of_teaching      5
# cct                                5
# nesta                              4
# ippo                               4
# national_audit_office              4
# national_literacy_trust            3
# Name: count, dtype: int64

# %%
# Extract unique URLs for each organisation
links_by_org = (
    df_filtered.groupby("organisation")["link_canonical"]
    .unique()
    .reset_index()
)

links_by_org
# Out:
#                      organisation  \
# 0              5rights_foundation
# 1                             bbc
# 2                            bera
# 3                 british_academy
# 4                             cct
# 5   chartered_college_of_teaching
# 6          childrens_commissioner
# 7                    conversation
# 8                             epi
# 9                             fed
# 10                 fft_ed_datalab
# 11                       guardian
# 12                            ifg
# 13                            ifs
# 14                           ippo
# 15                           ippr
# 16          national_audit_office
# 17        national_literacy_trust
# 18                          nesta
# 19                           nfer
# 20                       nuffield
# 21                   schools_week
# 22                   teacher_tapp
# 23                  uk_government
# 24                  uk_parliament
# 25                           ukri
# 26                           upen
#
#                                        link_canonical
# 0   [https://5rightsfoundation.com/in-action/inter...
# 1   [https://bbc.co.uk/news/education-68763942, ht...
# 2   [https://www.bera.ac.uk/blog/being-well-and-do...
# 3   [https://www.thebritishacademy.ac.uk/publicati...
# 4   [https://my.chartered.college/impact/issue-20-...
# 5   [https://chartered.college/rethinkingcurriculu...
# 6   [https://www.childrenscommissioner.gov.uk/medi...
# 7   [https://theconversation.com/minimum-service-l...
# 8   [https://epi.org.uk/publications-and-research/...
# 9   [https://fed.education/education-in-england-ne...
# 10  [https://ffteducationdatalab.org.uk/2023/09/ab...
# 11  [https://www.theguardian.com/education/2023/se...
# 12  [https://www.instituteforgovernment.org.uk/pub...
# 13  [https://ifs.org.uk/events/education-spending-...
# 14  [https://theippo.co.uk/how-evidence-can-help-d...
# 15  [https://www.ippr.org/research/publications/im...
# 16  [https://www.nao.org.uk/reports/support-for-ch...
# 17  [https://literacytrust.org.uk/research-service...
# 18  [https://www.nesta.org.uk/data-visualisation-a...
# 19  [https://www.nfer.ac.uk/policy-options-for-a-l...
# 20  [https://www.nuffieldfoundation.org/wp-content...
# 21  [https://schoolsweek.co.uk/chatgpt-keegan-laun...
# 22  [https://teachertapp.co.uk/articles/timetables...
# 23  [https://www.gov.uk/government/news/foreign-se...
# 24  [https://committees.parliament.uk/work/7912/sc...
# 25  [https://engagementhub.ukri.org/ahrc-operation...
# 26  [https://www.upen.ac.uk/blogs?story_id=958, ht...

# %%
gov_df = df[df["organisation"] == "uk_government"].copy()

# %%
gov_df.head()
# Out:
#                                       id  newsletter_number        issue_date  \
# 14  1b109222-dc42-4d14-92fc-c60320f919f7                  3      20 July 2023
# 16  d99471d0-fa6c-4fc2-8592-a9a96efff2f6                  3      20 July 2023
# 25  7991db15-4956-4f31-901e-a5957934fafa                  4      31 July 2023
# 29  def40c6f-570d-4086-bc87-0bb96da1b016                  4      31 July 2023
# 45  f41beec4-be12-43a8-b5fc-13c15d492c7b                  6  8 September 2023
#
#                          theme                                      subtheme  \
# 14            Thematic roundup                                       Digital
# 16            Thematic roundup  Teacher recruitment, retention & development
# 25            Thematic Roundup                                       Digital
# 29            Thematic Roundup  Teacher Recruitment, Retention & Development
# 45  What Matters in Education?                                           NaN
#
#                                                 title  \
# 14  FCDO - Foreign Secretary to call for internati...
# 16  Re pay awards: School Teachers' Review Body 33...
# 25  ChatGPT isn't the death of homework – just an ...
# 29  DfE - Teacher and Leader development: ECF and ...
# 45  Public Accounts Committee (PAC) - Government r...
#
#                                           description  \
# 14  Foreign Secretary to chair first ever UN Secur...
# 16  Recommendations from the School Teachers' Revi...
# 25  The UK government has launched a consultation ...
# 29  Across 21-22 and 22-23, 63,484 NPQ courses wer...
# 45  Some recommendations that the DfE will take ac...
#
#                                                  link        new_theme  \
# 14  https://www.gov.uk/government/news/foreign-sec...           edtech
# 16  https://www.gov.uk/government/publications/sch...      teacher_rrd
# 25  https://www.gov.uk/government/consultations/ge...           edtech
# 29  https://www.gov.uk/government/statistics/teach...      teacher_rrd
# 45  https://assets.publishing.service.gov.uk/gover...  what_matters_ed
#
#                             domain_x  ...  \
# 14                        www.gov.uk  ...
# 16                        www.gov.uk  ...
# 25                        www.gov.uk  ...
# 29                        www.gov.uk  ...
# 45  assets.publishing.service.gov.uk  ...
#
#                                                  text text_length_chars  \
# 14  FCDO - Foreign Secretary to call for internati...               448
# 16  Re pay awards: School Teachers' Review Body 33...               363
# 25  ChatGPT isn't the death of homework – just an ...               806
# 29  DfE - Teacher and Leader development: ECF and ...               321
# 45  Public Accounts Committee (PAC) - Government r...              1445
#
#    text_length_words                                     link_canonical  \
# 14                29  https://www.gov.uk/government/news/foreign-sec...
# 16                24  https://www.gov.uk/government/publications/sch...
# 25                48  https://www.gov.uk/government/consultations/ge...
# 29                55  https://www.gov.uk/government/statistics/teach...
# 45               213  https://assets.publishing.service.gov.uk/gover...
#
#                               article_id                          domain_y  \
# 14  7285ddf5-6a40-4f55-8e66-ae7253357067                        www.gov.uk
# 16  f30a398b-cea0-4d38-96e0-e238311bd803                        www.gov.uk
# 25  4d48ce8d-1b20-4af2-9d80-520adaa89f8e                        www.gov.uk
# 29  dde2ff67-c548-4fe8-9f7a-5aeb1b6783f5                        www.gov.uk
# 45  42ccf097-cf1e-487e-93e1-3ecc7b3d5f2a  assets.publishing.service.gov.uk
#
#                                         article_title  \
# 14  Foreign Secretary to call for international co...
# 16  School Teachers’ Review Body 33rd report: 2023...
# 25  Generative artificial intelligence in educatio...
# 29  Teacher and Leader development: ECF and NPQs 2...
# 45                                                NaN
#
#                                          article_text  status  failure_reason
# 14  Home Business and industry Science and innovat...      ok             NaN
# 16  Home Education, training and skills Teaching a...      ok             NaN
# 25  Home Education, training and skills Call for e...      ok             NaN
# 29  Home Education, training and skills Teaching a...      ok             NaN
# 45  %PDF-1.7 %���� 1598 0 obj < > endobj 1606 0 ob...      ok             NaN
#
# [5 rows x 27 columns]

# %%
# Extract unique links
gov_links = gov_df["link_canonical"].dropna().unique()

# %%
# Save
pd.DataFrame({"uk_government_links": gov_links}).to_csv(
    "/workspaces/ERP_Newsletter/data/data04_full_articles_scraped/uk_government_links.csv",
    index=False
)
