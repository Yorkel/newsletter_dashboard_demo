# %%
import pandas as pd

# %%
epi = pd.read_csv("/workspaces/ERP_Newsletter/data/data05_full_articles_selected/epi_articles_2023_2025.csv")
fed = pd.read_csv("/workspaces/ERP_Newsletter/data/data05_full_articles_selected/fed_news_resources.csv")
fft = pd.read_csv("/workspaces/ERP_Newsletter/data/data05_full_articles_selected/fft_education_datalab_blog.csv")
gov = pd.read_csv("/workspaces/ERP_Newsletter/data/data05_full_articles_selected/govuk_dfe_articles_2023_2025.csv")
nuffield = pd.read_csv("/workspaces/ERP_Newsletter/data/data05_full_articles_selected/nuffield_articles_2023_2025.csv")
schoolsweek = pd.read_csv("/workspaces/ERP_Newsletter/data/data05_full_articles_selected/schoolsweek_articles_2023_2025.csv")

# %%
datasets = {
    "epi": epi,
    "fed": fed,
    "fft": fft,
    "gov": gov,
    "nuffield": nuffield,
    "schoolsweek": schoolsweek,
}

for name, df in datasets.items():
    print(f"\n📄 {name.upper()}")
    print("Rows:", len(df))
    print("Columns:", df.columns.tolist())
# Out:
# 📄 EPI
# Rows: 115
# Columns: ['url', 'title', 'date', 'text', 'from', 'type']
#
# 📄 FED
# Rows: 106
# Columns: ['url', 'title', 'date', 'text', 'from', 'type']
#
# 📄 FFT
# Rows: 202
# Columns: ['url', 'title', 'date', 'text', 'from', 'type']
#
# 📄 GOV
# Rows: 1061
# Columns: ['url', 'title', 'from', 'date', 'text', 'type']
#
# 📄 NUFFIELD
# Rows: 107
# Columns: ['url', 'title', 'date', 'text', 'from', 'type']
#
# 📄 SCHOOLSWEEK
# Rows: 2742
# Columns: ['url', 'title', 'date', 'text', 'from', 'type']

# %%
epi["from"] = "epi"
epi["type"] = "think_tank"

nuffield["from"] = "nuffield"
nuffield["type"] = "think_tank"

fft["from"] = "fft"
fft["type"] = "ed_res_org"

fed["from"] = "fed"
fed["type"] = "prof_body"

schoolsweek["from"] = "schoolsweek"
schoolsweek["type"] = "ed_journalism"

gov["from"] = "gov"
gov["type"] = "government"

# %%
datasets = {
    "epi": epi,
    "fed": fed,
    "fft": fft,
    "gov": gov,
    "nuffield": nuffield,
    "schoolsweek": schoolsweek,
}

for name, df in datasets.items():
    print(f"\n📄 {name.upper()}")
    print("from:", df["from"].unique())
    print("type:", df["type"].unique())
# Out:
# 📄 EPI
# from: ['epi']
# type: ['think_tank']
#
# 📄 FED
# from: ['fed']
# type: ['prof_body']
#
# 📄 FFT
# from: ['fft']
# type: ['ed_res_org']
#
# 📄 GOV
# from: ['gov']
# type: ['government']
#
# 📄 NUFFIELD
# from: ['nuffield']
# type: ['think_tank']
#
# 📄 SCHOOLSWEEK
# from: ['schoolsweek']
# type: ['ed_journalism']

# %%
for name, df in datasets.items():
    print(f"\n📄 {name.upper()}")
    print(df[["url", "title", "date", "text"]].isna().sum())
# Out:
# 📄 EPI
# url      0
# title    0
# date     0
# text     0
# dtype: int64
#
# 📄 FED
# url      0
# title    0
# date     0
# text     0
# dtype: int64
#
# 📄 FFT
# url      0
# title    0
# date     0
# text     0
# dtype: int64
#
# 📄 GOV
# url      0
# title    0
# date     0
# text     0
# dtype: int64
#
# 📄 NUFFIELD
# url      0
# title    0
# date     0
# text     0
# dtype: int64
#
# 📄 SCHOOLSWEEK
# url      0
# title    0
# date     0
# text     0
# dtype: int64

# %%
fed[fed["text"].isna()][["url", "title", "date"]]
# Out:
#                                                   url  \
# 97  https://fed.education/fed-national-education-s...
# 98  https://fed.education/fed-national-education-s...
#
#                                                 title        date
# 97  FED National Education Summit 2023 Speaker Bio...  2023-06-16
# 98       FED National Education Summit 2023 Programme  2023-06-16

# %%
#drop rows in fed where text is missing  
fed = fed.dropna(subset=["text"])
fed = fed[fed["text"].str.strip() != ""]

# %%
datasets = {
    "epi": epi,
    "fed": fed,
    "fft": fft,
    "gov": gov,
    "nuffield": nuffield,
    "schoolsweek": schoolsweek,
}

# %%
for name, df in datasets.items():
    print(name, df.columns.tolist())
# Out:
# epi ['url', 'title', 'date', 'text', 'from', 'type']
# fed ['url', 'title', 'date', 'text', 'from', 'type']
# fft ['url', 'title', 'date', 'text', 'from', 'type']
# gov ['url', 'title', 'date', 'text', 'from', 'type']
# nuffield ['url', 'title', 'date', 'text', 'from', 'type']
# schoolsweek ['url', 'title', 'date', 'text', 'from', 'type']

# %% [markdown]
# # MERGE

# %%
cols = ["url", "title", "date", "text", "from", "type"]

epi = epi[cols]
fed = fed[cols]
fft = fft[cols]
gov = gov[cols]
nuffield = nuffield[cols]
schoolsweek = schoolsweek[cols]

# %%
full_retro = pd.concat(
    [epi, fed, fft, gov, nuffield, schoolsweek],
    ignore_index=True
)

# %%
print("Total rows:", len(full_retro))
print(full_retro["from"].value_counts())
print(full_retro["type"].value_counts())
# Out:
# Total rows: 4331
# from
# schoolsweek    2742
# gov            1061
# fft             202
# epi             115
# nuffield        107
# fed             104
# Name: count, dtype: int64
# type
# ed_journalism    2742
# government       1061
# think_tank        222
# ed_res_org        202
# prof_body         104
# Name: count, dtype: int64

# %%
#ensure date is datetime 
full_retro["date"] = pd.to_datetime(full_retro["date"], errors="coerce")

# %%
full_retro["date"].min(), full_retro["date"].max()
# Out:
# (Timestamp('2023-01-04 00:00:00'), Timestamp('2025-12-12 00:00:00'))
