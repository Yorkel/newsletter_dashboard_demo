# %%
import pandas as pd 
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/workspaces/ERP_Newsletter/data/data03_newsletter_items_clean/items_all_themes.csv")

# %%
df.head()
# Out:
#                                      id  newsletter_number    issue_date  \
# 0  c97ff62f-83ca-47ec-a4c7-b4e24157ae0a                  1  11 July 2023
# 1  e66a8dd2-0dce-444a-876c-3c8137ea2985                  1  11 July 2023
# 2  2ce7fa71-0b07-417c-a7d3-8d18e8f12716                  1  11 July 2023
# 3  64c74d6d-b558-4183-a42d-e7f0141ce527                  1  11 July 2023
# 4  5564ff61-bf33-482f-9010-32aea9ce1f73                  1  11 July 2023
#
#                               theme subtheme  \
# 0                Calls for evidence      NaN
# 1                               DfE      NaN
# 2                               DfE      NaN
# 3                               DfE      NaN
# 4  What are the politicians saying?      NaN
#
#                                                title  \
# 0                            Deadline 23 August 2023
# 1  Revealed: the experts advising ministers on te...
# 2  Reject fewer teacher applicants, DfE tells tra...
# 3  Ofqual and DfE studying 'feasibility' of 'full...
# 4  Revealed: The full details of Labour's educati...
#
#                                          description  \
# 0  Education secretary Gillian Keegan has launche...
# 1  The Department for Education has appointed an ...
# 2  Susan Acland-Hood, the DfE's permanent secreta...
# 3  Some exam boards are already piloting on-scree...
# 4  Entitled 'Breaking down the barrier to opportu...
#
#                                                 link  \
# 0  https://schoolsweek.co.uk/chatgpt-keegan-launc...
# 1  https://schoolsweek.co.uk/revealed-the-experts...
# 2  https://schoolsweek.co.uk/reject-fewer-teacher...
# 3  https://schoolsweek.co.uk/teachers-back-digita...
# 4  https://schoolsweek.co.uk/revealed-the-full-de...
#
#                                  new_theme
# 0  political_environment_key_organisations
# 1  political_environment_key_organisations
# 2  political_environment_key_organisations
# 3  political_environment_key_organisations
# 4  political_environment_key_organisations

# %%
df['new_theme'].value_counts().head(10)
# Out:
# new_theme
# political_environment_key_organisations    222
# what_matters_ed                            184
# teacher_rrd                                178
# edtech                                     167
# erp_project                                148
# policy_practice_research                   147
# four_nations                               112
# events_opportunities_research               34
# Name: count, dtype: int64

# %%
theme_counts = df['new_theme'].value_counts().head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=theme_counts.values, y=theme_counts.index)
plt.title("Top Themes")
plt.xlabel("Count")
plt.ylabel("Theme")
plt.show()

# %%
# group by MONTH and THEME
theme_time = (
    df.groupby([pd.Grouper(key='issue_date', freq='M'), 'new_theme'])
      .size()
      .reset_index(name='count')
)

plt.figure(figsize=(14, 7))
sns.lineplot(
    data=theme_time,
    x='issue_date',
    y='count',
    hue='new_theme',
    marker='o'
)

plt.title("Themes Over Time (Monthly)")
plt.xlabel("Month")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_32114/273843567.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.groupby([pd.Grouper(key='issue_date', freq='M'), 'new_theme'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # group by MONTH and THEME
#       2 theme_time = (
# ----> 3     df.groupby([pd.Grouper(key='issue_date', freq='M'), 'new_theme'])
#       4       .size()
#       5       .reset_index(name='count')
#       6 )
#       8 plt.figure(figsize=(14, 7))
#       9 sns.lineplot(
#      10     data=theme_time,
#      11     x='issue_date',
#    (...)     14     marker='o'
#      15 )
#
# File /workspaces/ERP_Newsletter/venv/lib/python3.12/site-packages/pandas/core/frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# File /workspaces/ERP_Newsletter/venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1331, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1328 self.dropna = dropna
#    1330 if grouper is None:
# -> 1331     grouper, exclusions, obj = get_grouper(
#    1332         obj,
#    1333         keys,
#    1334         axis=axis,
#    1335         level=level,
#    1336         sort=sort,
#    1337         observed=False if observed is lib.no_default else observed,
#    1338         dropna=self.dropna,
#    1339     )
#    1341 if observed is lib.no_default:
#    1342     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File /workspaces/ERP_Newsletter/venv/lib/python3.12/site-packages/pandas/core/groupby/grouper.py:1054, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1049         in_axis = False
#    1051     # create the Grouping
#    1052     # allow us to passing the actual Grouping as the gpr
#    1053     ping = (
# -> 1054         Grouping(
#    1055             group_axis,
#    1056             gpr,
#    1057             obj=obj,
#    1058             level=level,
#    1059             sort=sort,
#    1060             observed=observed,
#    1061             in_axis=in_axis,
#    1062             dropna=dropna,
#    1063         )
#    1064         if not isinstance(gpr, Grouping)
#    1065         else gpr
#    1066     )
#    1068     groupings.append(ping)
#    1070 if len(groupings) == 0 and len(obj):
#
# File /workspaces/ERP_Newsletter/venv/lib/python3.12/site-packages/pandas/core/groupby/grouper.py:579, in Grouping.__init__(self, index, grouper, obj, level, sort, observed, in_axis, dropna, uniques)
#     573 elif isinstance(grouping_vector, Grouper):
#     574     # get the new grouper; we already have disambiguated
#     575     # what key/level refer to exactly, don't need to
#     576     # check again as we have by this point converted these
#     577     # to an actual value (rather than a pd.Grouper)
#     578     assert self.obj is not None  # for mypy
# --> 579     newgrouper, newobj = grouping_vector._get_grouper(self.obj, validate=False)
#     580     self.obj = newobj
#     582     if isinstance(newgrouper, ops.BinGrouper):
#     583         # TODO: can we unwrap this and get a tighter typing
#     584         #  for self.grouping_vector?
#
# File /workspaces/ERP_Newsletter/venv/lib/python3.12/site-packages/pandas/core/resample.py:2268, in TimeGrouper._get_grouper(self, obj, validate)
#    2264 def _get_grouper(
#    2265     self, obj: NDFrameT, validate: bool = True
#    2266 ) -> tuple[BinGrouper, NDFrameT]:
#    2267     # create the resampler and return our binner
# -> 2268     r = self._get_resampler(obj)
#    2269     return r._grouper, cast(NDFrameT, r.obj)
#
# File /workspaces/ERP_Newsletter/venv/lib/python3.12/site-packages/pandas/core/resample.py:2258, in TimeGrouper._get_resampler(self, obj, kind)
#    2249 elif isinstance(ax, TimedeltaIndex):
#    2250     return TimedeltaIndexResampler(
#    2251         obj,
#    2252         timegrouper=self,
#    (...)   2255         gpr_index=ax,
#    2256     )
# -> 2258 raise TypeError(
#    2259     "Only valid with DatetimeIndex, "
#    2260     "TimedeltaIndex or PeriodIndex, "
#    2261     f"but got an instance of '{type(ax).__name__}'"
#    2262 )
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'

# %%
org_table = df['organisation'].value_counts().reset_index()
org_table.columns = ['organisation', 'count']

org_table.head(50)
# Out:
#                            organisation  count
# 0                          schools_week    143
# 1                         uk_government     67
# 2                                   ucl     54
# 3                          conversation     31
# 4                              guardian     28
# 5                                  bera     26
# 6                                  nfer     24
# 7                                   epi     24
# 8                   scottish_government     21
# 9                         uk_parliament     21
# 10                     welsh_government     21
# 11                                 oecd     18
# 12                        bera_journals     17
# 13                    belfast_telegraph     16
# 14                        ni_government     16
# 15                              twitter     15
# 16                                  tes     14
# 17                       fft_ed_datalab     14
# 18                                 upen     12
# 19             university_of_birmingham     12
# 20                                 ukri     11
# 21                             nuffield     11
# 22                      british_academy     11
# 23                         teacher_tapp     11
# 24                                  bbc     10
# 25                                  ifs      9
# 26               childrens_commissioner      9
# 27                                  ifg      9
# 28                                  fed      9
# 29                    oii_edtech_equity      8
# 30                                  eef      8
# 31                                  cct      7
# 32               house_of_lords_library      7
# 33                               wonkhe      6
# 34                   taylor_and_francis      6
# 35                      post_parliament      6
# 36                                 ippo      5
# 37        chartered_college_of_teaching      5
# 38                     welsh_parliament      5
# 39                             linkedin      5
# 40                   5rights_foundation      5
# 41                          independent      5
# 42  childrends_participation_in_schools      5
# 43   manchester_metropolitan_university      5
# 44                                 ippr      5
# 45             national_education_union      5
# 46                                nesta      4
# 47                                inews      4
# 48                national_audit_office      4
# 49                                 hepi      4

# %%
plt.figure(figsize=(10, 8))   # a bit taller for 20 labels

top20 = org_counts.head(20)

sns.barplot(x=top20.values, y=top20.index)

plt.xlabel("Count")
plt.ylabel("Organisation")
plt.title("Top 20 Organisations by Frequency")

plt.show()

# %%
org_time = df_top.groupby(['issue_date', 'organisation']).size().reset_index(name='count')

# %%
# make sure issue_date is datetime
df['issue_date'] = pd.to_datetime(df['issue_date'])

# pick top 5 orgs
org_counts = df['organisation'].value_counts()
top_orgs = org_counts.head(5).index

df_top = df[df['organisation'].isin(top_orgs)].copy()

# group by month + organisation
org_time = (
    df_top
    .groupby([pd.Grouper(key='issue_date', freq='M'), 'organisation'])
    .size()
    .reset_index(name='count')
)

plt.figure(figsize=(10, 6))
sns.lineplot(data=org_time, x='issue_date', y='count', hue='organisation', marker='o')
plt.title("Top 5 Organisations Over Time (Monthly)")
plt.xlabel("Month")
plt.ylabel("Number of mentions")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3526/1395032945.py:13: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   .groupby([pd.Grouper(key='issue_date', freq='M'), 'organisation'])

# %%
#theme distribution for single organisation 
org_name = "schools_week"   # change this
df[df['organisation'] == org_name]['new_theme'].value_counts().plot(
    kind='bar',
    figsize=(8, 5),
    title=f"Theme Distribution for {org_name}"
)
plt.show()
